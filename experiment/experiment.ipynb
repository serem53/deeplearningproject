# %% [markdown]
# ## getting data and defining necessary modules

# %%
pip install torchsummary
# Out:
# Requirement already satisfied: torchsummary in c:\users\hp\desktop\deeplearningproject\env\lib\site-packages (1.5.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\hp\desktop\deeplearningproject\env\lib\site-packages (4.9.0.80)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\hp\desktop\deeplearningproject\env\lib\site-packages (from opencv-python) (1.24.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import torch.nn.functional as F
from torchvision import datasets, transforms, models
from torch.optim.lr_scheduler import StepLR
from torchsummary import summary

import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
from PIL import Image
from IPython.display import display
from tqdm import tqdm

# %%
#%pwd
os.getcwd()
# Out:
# 'c:\\Users\\hp\\Desktop\\deeplearningproject\\artifacts\\02_25_2024_00_54_27\\data_ingestion\\chest_xray'

# %%
# changing the directory 
#os.chdir(r'../artifacts/02_25_2024_00_54_27/data_ingestion/chest_xray')

# %%
# %pwd
# Out:
# 'c:\\Users\\hp\\Desktop\\deeplearningproject\\artifacts\\02_25_2024_00_54_27\\data_ingestion\\chest_xray'

# %%
data_path=os.getcwd()

# %% [markdown]
# ## Exploring the data or images

# %%
# Defining the class name 
class_name = ['NORMAL','PNEUMONIA']

# %%
# Creating a function to  get the list of files
def get_list_of_files(dir_name):
    '''
    input - The input directory location
    output - Returns the list the files in the directory
    '''
    files_list = os.listdir(dir_name)
    return files_list

# %%
##defining path for train normal data path
train_normal_dir = data_path+'/train/'+class_name[0]

# %%
## getting images from train_data_dir
files_list_normal_train = get_list_of_files(train_normal_dir)

# %%
files_list_normal_train
# Out:
# ['NORMAL-1003233-0001.jpeg',
#  'NORMAL-1012843-0001.jpeg',
#  'NORMAL-1014768-0001.jpeg',
#  'NORMAL-1023731-0001.jpeg',
#  'NORMAL-1029510-0001.jpeg',
#  'NORMAL-1031320-0001.jpeg',
#  'NORMAL-1034239-0001.jpeg',
#  'NORMAL-1041364-0001.jpeg',
#  'NORMAL-1044645-0001.jpeg',
#  'NORMAL-1055663-0001.jpeg',
#  'NORMAL-1063934-0001.jpeg',
#  'NORMAL-1064313-0001.jpeg',
#  'NORMAL-1064313-0002.jpeg',
#  'NORMAL-1068231-0001.jpeg',
#  'NORMAL-1068326-0001.jpeg',
#  'NORMAL-1070073-0001.jpeg',
#  'NORMAL-1070073-0002.jpeg',
#  'NORMAL-1080088-0001.jpeg',
#  'NORMAL-1097039-0001.jpeg',
#  'NORMAL-1101909-0001.jpeg',
#  'NORMAL-1128157-0001.jpeg',
#  'NORMAL-1140710-0001.jpeg',
#  'NORMAL-1150393-0001.jpeg',
#  'NORMAL-1156778-0001.jpeg',
#  'NORMAL-1165014-0001.jpeg',
#  'NORMAL-1165014-0002.jpeg',
#  'NORMAL-1170804-0001.jpeg',
#  'NORMAL-1177627-0001.jpeg',
#  'NORMAL-1196989-0001.jpeg',
#  'NORMAL-1203236-0001.jpeg',
#  'NORMAL-1206638-0001.jpeg',
#  'NORMAL-1241506-0001.jpeg',
#  'NORMAL-1243491-0001.jpeg',
#  'NORMAL-1261648-0001.jpeg',
#  'NORMAL-1311502-0001.jpeg',
#  'NORMAL-1314288-0001.jpeg',
#  'NORMAL-1317636-0001.jpeg',
#  'NORMAL-132181-0001.jpeg',
#  'NORMAL-1323979-0001.jpeg',
#  'NORMAL-1325139-0001.jpeg',
#  'NORMAL-133685-0001.jpeg',
#  'NORMAL-1352927-0001.jpeg',
#  'NORMAL-1355454-0001.jpeg',
#  'NORMAL-137300-0001.jpeg',
#  'NORMAL-141619-0001.jpeg',
#  'NORMAL-1429145-0001.jpeg',
#  'NORMAL-1429145-0002.jpeg',
#  'NORMAL-1440428-0001.jpeg',
#  'NORMAL-1444388-0001.jpeg',
#  'NORMAL-1444388-0002.jpeg',
#  'NORMAL-145240-0001.jpeg',
#  'NORMAL-1455093-0001.jpeg',
#  'NORMAL-1456124-0001.jpeg',
#  'NORMAL-1456124-0002.jpeg',
#  'NORMAL-1457994-0001.jpeg',
#  'NORMAL-1465577-0001.jpeg',
#  'NORMAL-1476994-0001.jpeg',
#  'NORMAL-1482788-0001.jpeg',
#  'NORMAL-1504793-0001.jpeg',
#  'NORMAL-1505602-0001.jpeg',
#  'NORMAL-1505602-0002.jpeg',
#  'NORMAL-1507671-0001.jpeg',
#  'NORMAL-1507671-0002.jpeg',
#  'NORMAL-1507671-0003.jpeg',
#  'NORMAL-1513368-0001.jpeg',
#  'NORMAL-1522956-0001.jpeg',
#  'NORMAL-1528760-0001.jpeg',
#  'NORMAL-1530010-0001.jpeg',
#  'NORMAL-1530010-0002.jpeg',
#  'NORMAL-1533758-0001.jpeg',
#  'NORMAL-155211-0001.jpeg',
#  'NORMAL-1556834-0001.jpeg',
#  'NORMAL-1557045-0001.jpeg',
#  'NORMAL-1558430-0001.jpeg',
#  'NORMAL-1563073-0001.jpeg',
#  'NORMAL-1566405-0001.jpeg',
#  'NORMAL-1566442-0001.jpeg',
#  'NORMAL-1576353-0001.jpeg',
#  'NORMAL-1576353-0002.jpeg',
#  'NORMAL-1589680-0001.jpeg',
#  'NORMAL-159556-0001.jpeg',
#  'NORMAL-1602427-0001.jpeg',
#  'NORMAL-1602738-0001.jpeg',
#  'NORMAL-1602738-0002.jpeg',
#  'NORMAL-1619233-0001.jpeg',
#  'NORMAL-1696866-0001.jpeg',
#  'NORMAL-1697483-0001.jpeg',
#  'NORMAL-1699306-0001.jpeg',
#  'NORMAL-1701841-0001.jpeg',
#  'NORMAL-1702319-0001.jpeg',
#  'NORMAL-1702319-0002.jpeg',
#  'NORMAL-170867-0001.jpeg',
#  'NORMAL-170867-0002.jpeg',
#  'NORMAL-1715076-0001.jpeg',
#  'NORMAL-1739213-0001.jpeg',
#  'NORMAL-1756042-0001.jpeg',
#  'NORMAL-1769145-0001.jpeg',
#  'NORMAL-177055-0001.jpeg',
#  'NORMAL-177055-0002.jpeg',
#  'NORMAL-1770564-0001.jpeg',
#  'NORMAL-179015-0001.jpeg',
#  'NORMAL-1798503-0001.jpeg',
#  'NORMAL-1830070-0001.jpeg',
#  'NORMAL-1833676-0001.jpeg',
#  'NORMAL-183773-0001.jpeg',
#  'NORMAL-1842649-0001.jpeg',
#  'NORMAL-1843288-0001.jpeg',
#  'NORMAL-1860692-0001.jpeg',
#  'NORMAL-1862776-0001.jpeg',
#  'NORMAL-1866844-0001.jpeg',
#  'NORMAL-1870906-0001.jpeg',
#  'NORMAL-1897360-0001.jpeg',
#  'NORMAL-1897360-0002.jpeg',
#  'NORMAL-1898951-0001.jpeg',
#  'NORMAL-1901242-0001.jpeg',
#  'NORMAL-1914424-0001.jpeg',
#  'NORMAL-1915003-0001.jpeg',
#  'NORMAL-191707-0001.jpeg',
#  'NORMAL-1917089-0001.jpeg',
#  'NORMAL-1917089-0002.jpeg',
#  'NORMAL-191957-0001.jpeg',
#  'NORMAL-1930015-0001.jpeg',
#  'NORMAL-1932155-0001.jpeg',
#  'NORMAL-1934076-0001.jpeg',
#  'NORMAL-1941666-0001.jpeg',
#  'NORMAL-1955424-0001.jpeg',
#  'NORMAL-1958813-0001.jpeg',
#  'NORMAL-1958813-0002.jpeg',
#  'NORMAL-1996912-0001.jpeg',
#  'NORMAL-200474-0001.jpeg',
#  'NORMAL-2010074-0001.jpeg',
#  'NORMAL-2010074-0002.jpeg',
#  'NORMAL-202916-0001.jpeg',
#  'NORMAL-202916-0002.jpeg',
#  'NORMAL-202916-0003.jpeg',
#  'NORMAL-202916-0004.jpeg',
#  'NORMAL-2031622-0001.jpeg',
#  'NORMAL-2036386-0001.jpeg',
#  'NORMAL-2042112-0001.jpeg',
#  'NORMAL-2048417-0001.jpeg',
#  'NORMAL-2048417-0002.jpeg',
#  'NORMAL-2068214-0001.jpeg',
#  'NORMAL-2076945-0001.jpeg',
#  'NORMAL-2140240-0001.jpeg',
#  'NORMAL-2140240-0002.jpeg',
#  'NORMAL-2150838-0001.jpeg',
#  'NORMAL-2154341-0001.jpeg',
#  'NORMAL-2154341-0002.jpeg',
#  'NORMAL-2162388-0001.jpeg',
#  'NORMAL-2180796-0001.jpeg',
#  'NORMAL-2187139-0001.jpeg',
#  'NORMAL-2204525-0001.jpeg',
#  'NORMAL-2204525-0002.jpeg',
#  'NORMAL-2204525-0003.jpeg',
#  'NORMAL-2211620-0001.jpeg',
#  'NORMAL-2214391-0001.jpeg',
#  'NORMAL-2214391-0002.jpeg',
#  'NORMAL-221753-0001.jpeg',
#  'NORMAL-2230350-0001.jpeg',
#  'NORMAL-2233981-0001.jpeg',
#  'NORMAL-2239107-0001.jpeg',
#  'NORMAL-2239107-0002.jpeg',
#  'NORMAL-2239107-0003.jpeg',
#  'NORMAL-2239132-0001.jpeg',
#  'NORMAL-2239178-0001.jpeg',
#  'NORMAL-2239455-0001.jpeg',
#  'NORMAL-2244273-0001.jpeg',
#  'NORMAL-2253299-0001.jpeg',
#  'NORMAL-2255274-0001.jpeg',
#  'NORMAL-2257508-0001.jpeg',
#  'NORMAL-2257508-0002.jpeg',
#  'NORMAL-2272901-0001.jpeg',
#  'NORMAL-2280482-0001.jpeg',
#  'NORMAL-2282444-0001.jpeg',
#  'NORMAL-2285600-0001.jpeg',
#  'NORMAL-2285600-0002.jpeg',
#  'NORMAL-229022-0001.jpeg',
#  'NORMAL-230877-0001.jpeg',
#  'NORMAL-2315098-0001.jpeg',
#  'NORMAL-233341-0001.jpeg',
#  'NORMAL-2333546-0001.jpeg',
#  'NORMAL-2333546-0002.jpeg',
#  'NORMAL-2333546-0003.jpeg',
#  'NORMAL-2333546-0004.jpeg',
#  'NORMAL-2335549-0001.jpeg',
#  'NORMAL-2335856-0001.jpeg',
#  'NORMAL-2337422-0001.jpeg',
#  'NORMAL-2338211-0001.jpeg',
#  'NORMAL-2339168-0001.jpeg',
#  'NORMAL-2344710-0001.jpeg',
#  'NORMAL-2344710-0002.jpeg',
#  'NORMAL-2362538-0001.jpeg',
#  'NORMAL-2386123-0001.jpeg',
#  'NORMAL-2386444-0001.jpeg',
#  'NORMAL-2387301-0001.jpeg',
#  'NORMAL-2394904-0001.jpeg',
#  'NORMAL-239549-0001.jpeg',
#  'NORMAL-2395964-0001.jpeg',
#  'NORMAL-2395964-0002.jpeg',
#  'NORMAL-2411226-0001.jpeg',
#  'NORMAL-2415019-0001.jpeg',
#  'NORMAL-2415177-0001.jpeg',
#  'NORMAL-2416577-0001.jpeg',
#  'NORMAL-2416577-0002.jpeg',
#  'NORMAL-2416577-0003.jpeg',
#  'NORMAL-2416577-0004.jpeg',
#  'NORMAL-2432050-0001.jpeg',
#  'NORMAL-2451318-0001.jpeg',
#  'NORMAL-2460811-0001.jpeg',
#  'NORMAL-2460811-0002.jpeg',
#  'NORMAL-2469830-0001.jpeg',
#  'NORMAL-2474988-0001.jpeg',
#  'NORMAL-2481508-0001.jpeg',
#  'NORMAL-2487179-0001.jpeg',
#  'NORMAL-2491954-0001.jpeg',
#  'NORMAL-2504415-0001.jpeg',
#  'NORMAL-2504415-0002.jpeg',
#  'NORMAL-2517971-0001.jpeg',
#  'NORMAL-2521614-0001.jpeg',
#  'NORMAL-2523281-0001.jpeg',
#  'NORMAL-252489-0001.jpeg',
#  'NORMAL-2528215-0001.jpeg',
#  'NORMAL-2537399-0001.jpeg',
#  'NORMAL-2537399-0002.jpeg',
#  'NORMAL-2541618-0001.jpeg',
#  'NORMAL-2550592-0001.jpeg',
#  'NORMAL-2550592-0002.jpeg',
#  'NORMAL-2550592-0003.jpeg',
#  'NORMAL-2550782-0001.jpeg',
#  'NORMAL-2552119-0001.jpeg',
#  'NORMAL-2552119-0002.jpeg',
#  'NORMAL-2552119-0003.jpeg',
#  'NORMAL-2558319-0001.jpeg',
#  'NORMAL-2558319-0002.jpeg',
#  'NORMAL-2559035-0001.jpeg',
#  'NORMAL-2559035-0002.jpeg',
#  'NORMAL-2565226-0001.jpeg',
#  'NORMAL-2568157-0001.jpeg',
#  'NORMAL-2597757-0001.jpeg',
#  'NORMAL-2597757-0002.jpeg',
#  'NORMAL-263932-0001.jpeg',
#  'NORMAL-2646645-0001.jpeg',
#  'NORMAL-2646923-0001.jpeg',
#  'NORMAL-2655558-0001.jpeg',
#  'NORMAL-2659844-0001.jpeg',
#  'NORMAL-2675017-0001.jpeg',
#  'NORMAL-2675017-0002.jpeg',
#  'NORMAL-2689107-0001.jpeg',
#  'NORMAL-2692080-0001.jpeg',
#  'NORMAL-2695944-0001.jpeg',
#  'NORMAL-2697110-0001.jpeg',
#  'NORMAL-2697110-0002.jpeg',
#  'NORMAL-2699389-0001.jpeg',
#  'NORMAL-2699389-0002.jpeg',
#  'NORMAL-2705424-0001.jpeg',
#  'NORMAL-2705424-0002.jpeg',
#  'NORMAL-2705424-0003.jpeg',
#  'NORMAL-2723350-0001.jpeg',
#  'NORMAL-2723532-0001.jpeg',
#  'NORMAL-2728496-0001.jpeg',
#  'NORMAL-2736751-0001.jpeg',
#  'NORMAL-275284-0001.jpeg',
#  'NORMAL-2768393-0001.jpeg',
#  'NORMAL-2768393-0002.jpeg',
#  'NORMAL-2768393-0003.jpeg',
#  'NORMAL-2768393-0004.jpeg',
#  'NORMAL-2768393-0005.jpeg',
#  'NORMAL-2768393-0006.jpeg',
#  'NORMAL-2779359-0001.jpeg',
#  'NORMAL-2801235-0001.jpeg',
#  'NORMAL-2808220-0001.jpeg',
#  'NORMAL-2823265-0001.jpeg',
#  'NORMAL-284113-0001.jpeg',
#  'NORMAL-284113-0002.jpeg',
#  'NORMAL-284113-0003.jpeg',
#  'NORMAL-28501-0001.jpeg',
#  'NORMAL-2860555-0001.jpeg',
#  'NORMAL-2881687-0001.jpeg',
#  'NORMAL-2881863-0001.jpeg',
#  'NORMAL-2885344-0001.jpeg',
#  'NORMAL-2890238-0001.jpeg',
#  'NORMAL-2914942-0001.jpeg',
#  'NORMAL-2926567-0001.jpeg',
#  'NORMAL-293382-0001.jpeg',
#  'NORMAL-2949692-0001.jpeg',
#  'NORMAL-2957919-0001.jpeg',
#  'NORMAL-2983256-0001.jpeg',
#  'NORMAL-2984327-0001.jpeg',
#  'NORMAL-2986373-0001.jpeg',
#  'NORMAL-2992797-0001.jpeg',
#  'NORMAL-2992797-0002.jpeg',
#  'NORMAL-2996766-0001.jpeg',
#  'NORMAL-3006949-0001.jpeg',
#  'NORMAL-3006949-0002.jpeg',
#  'NORMAL-3037101-0001.jpeg',
#  'NORMAL-3040444-0001.jpeg',
#  'NORMAL-3054452-0001.jpeg',
#  'NORMAL-3072074-0001.jpeg',
#  'NORMAL-3073180-0001.jpeg',
#  'NORMAL-3079343-0001.jpeg',
#  'NORMAL-3103404-0001.jpeg',
#  'NORMAL-3103404-0002.jpeg',
#  'NORMAL-3108988-0001.jpeg',
#  'NORMAL-3119430-0001.jpeg',
#  'NORMAL-3144575-0001.jpeg',
#  'NORMAL-3147147-0001.jpeg',
#  'NORMAL-3156332-0001.jpeg',
#  'NORMAL-3156332-0002.jpeg',
#  'NORMAL-3168931-0001.jpeg',
#  'NORMAL-3170978-0001.jpeg',
#  'NORMAL-3175147-0001.jpeg',
#  'NORMAL-3175147-0002.jpeg',
#  'NORMAL-3175613-0001.jpeg',
#  'NORMAL-3178986-0001.jpeg',
#  'NORMAL-3178986-0002.jpeg',
#  'NORMAL-3190806-0001.jpeg',
#  'NORMAL-3194625-0001.jpeg',
#  'NORMAL-3207024-0001.jpeg',
#  'NORMAL-3220570-0001.jpeg',
#  'NORMAL-3220570-0002.jpeg',
#  'NORMAL-3220570-0003.jpeg',
#  'NORMAL-3220570-0004.jpeg',
#  'NORMAL-3229529-0001.jpeg',
#  'NORMAL-3229887-0001.jpeg',
#  'NORMAL-3229887-0002.jpeg',
#  'NORMAL-32326-0001.jpeg',
#  'NORMAL-3243013-0001.jpeg',
#  'NORMAL-324309-0001.jpeg',
#  'NORMAL-3250852-0001.jpeg',
#  'NORMAL-3260755-0001.jpeg',
#  'NORMAL-3269314-0001.jpeg',
#  'NORMAL-3271929-0001.jpeg',
#  'NORMAL-3271929-0002.jpeg',
#  'NORMAL-332359-0001.jpeg',
#  'NORMAL-3333785-0001.jpeg',
#  'NORMAL-3333785-0002.jpeg',
#  'NORMAL-3342765-0001.jpeg',
#  'NORMAL-3342765-0002.jpeg',
#  'NORMAL-3360834-0001.jpeg',
#  'NORMAL-3371493-0001.jpeg',
#  'NORMAL-3373762-0001.jpeg',
#  'NORMAL-3375999-0001.jpeg',
#  'NORMAL-3387483-0001.jpeg',
#  'NORMAL-3387483-0002.jpeg',
#  'NORMAL-338872-0001.jpeg',
#  'NORMAL-339692-0001.jpeg',
#  'NORMAL-339692-0002.jpeg',
#  'NORMAL-3399582-0001.jpeg',
#  'NORMAL-3399582-0002.jpeg',
#  'NORMAL-3400382-0001.jpeg',
#  'NORMAL-3400382-0002.jpeg',
#  'NORMAL-3402813-0001.jpeg',
#  'NORMAL-3411116-0001.jpeg',
#  'NORMAL-3411116-0002.jpeg',
#  'NORMAL-3411116-0003.jpeg',
#  'NORMAL-3444356-0001.jpeg',
#  'NORMAL-3448549-0001.jpeg',
#  'NORMAL-3476904-0001.jpeg',
#  'NORMAL-3482198-0001.jpeg',
#  'NORMAL-3482198-0002.jpeg',
#  'NORMAL-3482198-0003.jpeg',
#  'NORMAL-3482198-0004.jpeg',
#  'NORMAL-3484856-0001.jpeg',
#  'NORMAL-3486729-0001.jpeg',
#  'NORMAL-3487615-0001.jpeg',
#  'NORMAL-3493370-0001.jpeg',
#  'NORMAL-3502771-0001.jpeg',
#  'NORMAL-3502771-0002.jpeg',
#  'NORMAL-3514363-0001.jpeg',
#  'NORMAL-3514363-0002.jpeg',
#  'NORMAL-3514363-0003.jpeg',
#  'NORMAL-3514363-0004.jpeg',
#  'NORMAL-3518933-0001.jpeg',
#  'NORMAL-3518933-0002.jpeg',
#  'NORMAL-3518986-0001.jpeg',
#  'NORMAL-3526928-0001.jpeg',
#  'NORMAL-3526928-0002.jpeg',
#  'NORMAL-3532468-0001.jpeg',
#  'NORMAL-3570271-0001.jpeg',
#  'NORMAL-3573766-0001.jpeg',
#  'NORMAL-3573766-0002.jpeg',
#  'NORMAL-3573766-0003.jpeg',
#  'NORMAL-3573766-0004.jpeg',
#  'NORMAL-3580922-0001.jpeg',
#  'NORMAL-3624836-0001.jpeg',
#  'NORMAL-3644944-0001.jpeg',
#  'NORMAL-3644944-0002.jpeg',
#  'NORMAL-3644944-0003.jpeg',
#  'NORMAL-3665449-0001.jpeg',
#  'NORMAL-3678361-0001.jpeg',
#  'NORMAL-3684474-0001.jpeg',
#  'NORMAL-3685250-0001.jpeg',
#  'NORMAL-3688916-0001.jpeg',
#  'NORMAL-3688916-0002.jpeg',
#  'NORMAL-3706164-0001.jpeg',
#  'NORMAL-3744309-0001.jpeg',
#  'NORMAL-3744578-0001.jpeg',
#  'NORMAL-3747940-0001.jpeg',
#  'NORMAL-3751100-0001.jpeg',
#  'NORMAL-3758513-0001.jpeg',
#  'NORMAL-3758513-0002.jpeg',
#  'NORMAL-3758513-0003.jpeg',
#  'NORMAL-3758513-0004.jpeg',
#  'NORMAL-3780378-0001.jpeg',
#  'NORMAL-3780378-0002.jpeg',
#  'NORMAL-3780378-0003.jpeg',
#  'NORMAL-3781678-0001.jpeg',
#  'NORMAL-3781678-0002.jpeg',
#  'NORMAL-3789615-0001.jpeg',
#  'NORMAL-3789615-0002.jpeg',
#  'NORMAL-3802540-0001.jpeg',
#  'NORMAL-3802540-0002.jpeg',
#  'NORMAL-3802697-0001.jpeg',
#  'NORMAL-3803096-0001.jpeg',
#  'NORMAL-3821719-0001.jpeg',
#  'NORMAL-3823741-0001.jpeg',
#  'NORMAL-3848106-0001.jpeg',
#  'NORMAL-3848106-0002.jpeg',
#  'NORMAL-3852346-0001.jpeg',
#  'NORMAL-3852346-0002.jpeg',
#  'NORMAL-3852346-0003.jpeg',
#  'NORMAL-3853078-0001.jpeg',
#  'NORMAL-3853078-0002.jpeg',
#  'NORMAL-3853265-0001.jpeg',
#  'NORMAL-385855-0001.jpeg',
#  'NORMAL-385855-0002.jpeg',
#  'NORMAL-385855-0003.jpeg',
#  'NORMAL-385855-0004.jpeg',
#  'NORMAL-385855-0005.jpeg',
#  'NORMAL-3860648-0001.jpeg',
#  'NORMAL-3860648-0002.jpeg',
#  'NORMAL-3861947-0001.jpeg',
#  'NORMAL-3861947-0002.jpeg',
#  'NORMAL-3873301-0001.jpeg',
#  'NORMAL-3873301-0002.jpeg',
#  'NORMAL-3881206-0001.jpeg',
#  'NORMAL-388586-0001.jpeg',
#  'NORMAL-388586-0002.jpeg',
#  'NORMAL-388586-0003.jpeg',
#  'NORMAL-3895972-0001.jpeg',
#  'NORMAL-3902817-0001.jpeg',
#  'NORMAL-390699-0001.jpeg',
#  'NORMAL-3907168-0001.jpeg',
#  'NORMAL-3908973-0001.jpeg',
#  'NORMAL-3948906-0001.jpeg',
#  'NORMAL-3948906-0002.jpeg',
#  'NORMAL-3949386-0001.jpeg',
#  'NORMAL-3949386-0002.jpeg',
#  'NORMAL-3952204-0001.jpeg',
#  'NORMAL-3958628-0001.jpeg',
#  'NORMAL-3964800-0001.jpeg',
#  'NORMAL-3964800-0002.jpeg',
#  'NORMAL-3969882-0001.jpeg',
#  'NORMAL-3969882-0002.jpeg',
#  'NORMAL-3975363-0001.jpeg',
#  'NORMAL-3982198-0001.jpeg',
#  'NORMAL-3997421-0001.jpeg',
#  'NORMAL-4008560-0001.jpeg',
#  'NORMAL-4019172-0001.jpeg',
#  'NORMAL-4019172-0002.jpeg',
#  'NORMAL-4019172-0003.jpeg',
#  'NORMAL-4027257-0001.jpeg',
#  'NORMAL-4047118-0001.jpeg',
#  'NORMAL-4051219-0001.jpeg',
#  'NORMAL-4056615-0001.jpeg',
#  'NORMAL-4056615-0002.jpeg',
#  'NORMAL-4090456-0001.jpeg',
#  'NORMAL-4092650-0001.jpeg',
#  'NORMAL-4092650-0002.jpeg',
#  'NORMAL-4093513-0001.jpeg',
#  'NORMAL-4099158-0001.jpeg',
#  'NORMAL-4119877-0001.jpeg',
#  'NORMAL-4122298-0001.jpeg',
#  'NORMAL-4159337-0001.jpeg',
#  'NORMAL-4164846-0001.jpeg',
#  'NORMAL-4164846-0002.jpeg',
#  'NORMAL-4173304-0001.jpeg',
#  'NORMAL-4175731-0001.jpeg',
#  'NORMAL-4178256-0001.jpeg',
#  'NORMAL-4178405-0001.jpeg',
#  'NORMAL-4178405-0002.jpeg',
#  'NORMAL-4179172-0001.jpeg',
#  'NORMAL-4184691-0001.jpeg',
#  'NORMAL-4190635-0001.jpeg',
#  'NORMAL-4199443-0001.jpeg',
#  'NORMAL-4199443-0002.jpeg',
#  'NORMAL-4205289-0001.jpeg',
#  'NORMAL-4212770-0001.jpeg',
#  'NORMAL-4221981-0001.jpeg',
#  'NORMAL-4221981-0002.jpeg',
#  'NORMAL-4223385-0001.jpeg',
#  'NORMAL-4234436-0001.jpeg',
#  'NORMAL-4240389-0001.jpeg',
#  'NORMAL-4241389-0001.jpeg',
#  'NORMAL-4241389-0002.jpeg',
#  'NORMAL-4241606-0001.jpeg',
#  'NORMAL-4241606-0002.jpeg',
#  'NORMAL-4267417-0001.jpeg',
#  'NORMAL-4271375-0001.jpeg',
#  'NORMAL-4286410-0001.jpeg',
#  'NORMAL-4296383-0001.jpeg',
#  'NORMAL-431263-0001.jpeg',
#  'NORMAL-4314990-0001.jpeg',
#  'NORMAL-4316614-0001.jpeg',
#  'NORMAL-4316614-0002.jpeg',
#  'NORMAL-4317334-0001.jpeg',
#  'NORMAL-4320287-0001.jpeg',
#  'NORMAL-4320287-0002.jpeg',
#  'NORMAL-4358449-0001.jpeg',
#  'NORMAL-4358449-0002.jpeg',
#  'NORMAL-4377146-0001.jpeg',
#  'NORMAL-4418958-0001.jpeg',
#  'NORMAL-4418958-0002.jpeg',
#  'NORMAL-4418958-0003.jpeg',
#  'NORMAL-4418958-0004.jpeg',
#  'NORMAL-4421061-0001.jpeg',
#  'NORMAL-4447575-0001.jpeg',
#  'NORMAL-445267-0001.jpeg',
#  'NORMAL-4464072-0001.jpeg',
#  'NORMAL-447225-0001.jpeg',
#  'NORMAL-4486854-0001.jpeg',
#  'NORMAL-4496165-0001.jpeg',
#  'NORMAL-4499436-0001.jpeg',
#  'NORMAL-4500184-0001.jpeg',
#  'NORMAL-4507677-0001.jpeg',
#  'NORMAL-4507677-0002.jpeg',
#  'NORMAL-4515478-0001.jpeg',
#  'NORMAL-4515478-0002.jpeg',
#  'NORMAL-4515541-0001.jpeg',
#  'NORMAL-4521403-0001.jpeg',
#  'NORMAL-452722-0001.jpeg',
#  'NORMAL-4528586-0001.jpeg',
#  'NORMAL-4557620-0001.jpeg',
#  'NORMAL-4587209-0001.jpeg',
#  'NORMAL-4587209-0002.jpeg',
#  'NORMAL-4587209-0003.jpeg',
#  'NORMAL-4605989-0001.jpeg',
#  'NORMAL-4612356-0001.jpeg',
#  'NORMAL-4617560-0001.jpeg',
#  'NORMAL-462175-0001.jpeg',
#  'NORMAL-462175-0002.jpeg',
#  'NORMAL-4635177-0001.jpeg',
#  'NORMAL-4638373-0001.jpeg',
#  'NORMAL-4649665-0001.jpeg',
#  'NORMAL-4656588-0001.jpeg',
#  'NORMAL-4663193-0001.jpeg',
#  'NORMAL-4669070-0001.jpeg',
#  'NORMAL-4669070-0002.jpeg',
#  'NORMAL-4678619-0001.jpeg',
#  'NORMAL-4678619-0002.jpeg',
#  'NORMAL-4680404-0001.jpeg',
#  'NORMAL-4680404-0002.jpeg',
#  'NORMAL-4680404-0003.jpeg',
#  'NORMAL-4680404-0004.jpeg',
#  'NORMAL-4688588-0001.jpeg',
#  'NORMAL-4689461-0001.jpeg',
#  'NORMAL-4694540-0001.jpeg',
#  'NORMAL-471048-0001.jpeg',
#  'NORMAL-471293-0001.jpeg',
#  'NORMAL-473372-0001.jpeg',
#  'NORMAL-4734216-0001.jpeg',
#  'NORMAL-4735535-0001.jpeg',
#  'NORMAL-4748580-0001.jpeg',
#  'NORMAL-4751528-0001.jpeg',
#  'NORMAL-4758820-0001.jpeg',
#  'NORMAL-4758820-0002.jpeg',
#  'NORMAL-4758820-0003.jpeg',
#  'NORMAL-4769977-0001.jpeg',
#  'NORMAL-4769977-0002.jpeg',
#  'NORMAL-4786732-0001.jpeg',
#  'NORMAL-4791400-0001.jpeg',
#  'NORMAL-4791400-0002.jpeg',
#  'NORMAL-4798472-0001.jpeg',
#  'NORMAL-4824082-0001.jpeg',
#  'NORMAL-4829481-0001.jpeg',
#  'NORMAL-483610-0001.jpeg',
#  'NORMAL-4839411-0001.jpeg',
#  'NORMAL-4843653-0001.jpeg',
#  'NORMAL-4853105-0001.jpeg',
#  'NORMAL-4859175-0001.jpeg',
#  'NORMAL-4867871-0001.jpeg',
#  'NORMAL-4900810-0001.jpeg',
#  'NORMAL-4942258-0001.jpeg',
#  'NORMAL-4943890-0001.jpeg',
#  'NORMAL-4946392-0001.jpeg',
#  'NORMAL-4951226-0001.jpeg',
#  'NORMAL-4969331-0001.jpeg',
#  'NORMAL-4973676-0001.jpeg',
#  'NORMAL-4982187-0001.jpeg',
#  'NORMAL-4994733-0001.jpeg',
#  'NORMAL-5001531-0001.jpeg',
#  'NORMAL-5008447-0001.jpeg',
#  'NORMAL-5015362-0001.jpeg',
#  'NORMAL-5021371-0001.jpeg',
#  'NORMAL-5031579-0001.jpeg',
#  'NORMAL-5031579-0002.jpeg',
#  'NORMAL-5042453-0001.jpeg',
#  'NORMAL-5042453-0002.jpeg',
#  'NORMAL-5049026-0001.jpeg',
#  'NORMAL-5050179-0001.jpeg',
#  'NORMAL-5061991-0001.jpeg',
#  'NORMAL-506998-0001.jpeg',
#  'NORMAL-5075834-0001.jpeg',
#  'NORMAL-5075834-0002.jpeg',
#  'NORMAL-5080539-0001.jpeg',
#  'NORMAL-5082504-0001.jpeg',
#  'NORMAL-5087693-0001.jpeg',
#  'NORMAL-508988-0001.jpeg',
#  'NORMAL-5090771-0001.jpeg',
#  'NORMAL-5126891-0001.jpeg',
#  'NORMAL-5161959-0001.jpeg',
#  'NORMAL-5170916-0001.jpeg',
#  'NORMAL-5176049-0001.jpeg',
#  'NORMAL-518175-0001.jpeg',
#  'NORMAL-5187821-0001.jpeg',
#  'NORMAL-5222567-0001.jpeg',
#  'NORMAL-5227108-0001.jpeg',
#  'NORMAL-5227306-0001.jpeg',
#  'NORMAL-5234465-0001.jpeg',
#  'NORMAL-5236765-0001.jpeg',
#  'NORMAL-5240418-0001.jpeg',
#  'NORMAL-5243995-0001.jpeg',
#  'NORMAL-5264964-0001.jpeg',
#  'NORMAL-5270355-0001.jpeg',
#  'NORMAL-5277056-0001.jpeg',
#  'NORMAL-5288174-0001.jpeg',
#  'NORMAL-5315468-0001.jpeg',
#  'NORMAL-5332597-0001.jpeg',
#  'NORMAL-534646-0001.jpeg',
#  'NORMAL-5355820-0001.jpeg',
#  'NORMAL-5355820-0002.jpeg',
#  'NORMAL-5355820-0003.jpeg',
#  'NORMAL-5357348-0001.jpeg',
#  'NORMAL-5379127-0001.jpeg',
#  'NORMAL-5386916-0001.jpeg',
#  'NORMAL-5387596-0001.jpeg',
#  'NORMAL-5389167-0001.jpeg',
#  'NORMAL-5397211-0001.jpeg',
#  'NORMAL-5397211-0002.jpeg',
#  'NORMAL-5398062-0001.jpeg',
#  'NORMAL-5401202-0001.jpeg',
#  'NORMAL-5401202-0002.jpeg',
#  'NORMAL-5401202-0003.jpeg',
#  'NORMAL-5401202-0004.jpeg',
#  'NORMAL-5409923-0001.jpeg',
#  'NORMAL-5422966-0001.jpeg',
#  'NORMAL-5426353-0001.jpeg',
#  'NORMAL-5426353-0002.jpeg',
#  'NORMAL-5426353-0003.jpeg',
#  'NORMAL-5427599-0001.jpeg',
#  'NORMAL-5430880-0001.jpeg',
#  'NORMAL-5431669-0001.jpeg',
#  'NORMAL-5452786-0001.jpeg',
#  'NORMAL-546828-0001.jpeg',
#  'NORMAL-5488799-0001.jpeg',
#  'NORMAL-5488799-0002.jpeg',
#  'NORMAL-5504914-0001.jpeg',
#  'NORMAL-5505017-0001.jpeg',
#  'NORMAL-5505017-0002.jpeg',
#  'NORMAL-5505017-0003.jpeg',
#  'NORMAL-5505017-0004.jpeg',
#  'NORMAL-5514751-0001.jpeg',
#  'NORMAL-5528656-0001.jpeg',
#  'NORMAL-5543895-0001.jpeg',
#  'NORMAL-5545083-0001.jpeg',
#  'NORMAL-5545083-0002.jpeg',
#  'NORMAL-5571242-0001.jpeg',
#  'NORMAL-5571242-0002.jpeg',
#  'NORMAL-5571242-0003.jpeg',
#  'NORMAL-557197-0001.jpeg',
#  'NORMAL-5575488-0001.jpeg',
#  'NORMAL-559372-0001.jpeg',
#  'NORMAL-5602301-0001.jpeg',
#  'NORMAL-5606086-0001.jpeg',
#  'NORMAL-5618998-0001.jpeg',
#  'NORMAL-5623914-0001.jpeg',
#  'NORMAL-5633781-0001.jpeg',
#  'NORMAL-5633781-0002.jpeg',
#  'NORMAL-5634312-0001.jpeg',
#  'NORMAL-5634312-0002.jpeg',
#  'NORMAL-5638457-0001.jpeg',
#  'NORMAL-5650764-0001.jpeg',
#  'NORMAL-5650764-0002.jpeg',
#  'NORMAL-5650764-0003.jpeg',
#  'NORMAL-5651147-0001.jpeg',
#  'NORMAL-5659176-0001.jpeg',
#  'NORMAL-5661210-0001.jpeg',
#  'NORMAL-566227-0001.jpeg',
#  'NORMAL-566227-0002.jpeg',
#  'NORMAL-5673735-0001.jpeg',
#  'NORMAL-5676630-0001.jpeg',
#  'NORMAL-5693915-0001.jpeg',
#  'NORMAL-5693915-0002.jpeg',
#  'NORMAL-5693915-0003.jpeg',
#  'NORMAL-5693915-0004.jpeg',
#  'NORMAL-5708108-0001.jpeg',
#  'NORMAL-5708209-0001.jpeg',
#  'NORMAL-5722320-0001.jpeg',
#  'NORMAL-5724628-0001.jpeg',
#  'NORMAL-5726309-0001.jpeg',
#  'NORMAL-5728847-0001.jpeg',
#  'NORMAL-5728847-0002.jpeg',
#  'NORMAL-5729327-0001.jpeg',
#  'NORMAL-5729564-0001.jpeg',
#  'NORMAL-5729564-0002.jpeg',
#  'NORMAL-5740995-0001.jpeg',
#  'NORMAL-5740995-0002.jpeg',
#  'NORMAL-5745959-0001.jpeg',
#  'NORMAL-5748384-0001.jpeg',
#  'NORMAL-5752258-0001.jpeg',
#  'NORMAL-5759621-0001.jpeg',
#  'NORMAL-5759621-0002.jpeg',
#  'NORMAL-5762763-0001.jpeg',
#  'NORMAL-5791834-0001.jpeg',
#  'NORMAL-5799769-0001.jpeg',
#  'NORMAL-5802954-0001.jpeg',
#  'NORMAL-5816980-0001.jpeg',
#  'NORMAL-5816980-0002.jpeg',
#  'NORMAL-5833288-0001.jpeg',
#  'NORMAL-5840376-0001.jpeg',
#  'NORMAL-5845895-0001.jpeg',
#  'NORMAL-5849113-0001.jpeg',
#  'NORMAL-5850175-0001.jpeg',
#  'NORMAL-5877265-0001.jpeg',
#  'NORMAL-5881224-0001.jpeg',
#  'NORMAL-5887026-0001.jpeg',
#  'NORMAL-5887943-0001.jpeg',
#  'NORMAL-591136-0001.jpeg',
#  'NORMAL-5911363-0001.jpeg',
#  'NORMAL-5911363-0002.jpeg',
#  'NORMAL-5918516-0001.jpeg',
#  'NORMAL-5918516-0002.jpeg',
#  'NORMAL-5918516-0003.jpeg',
#  'NORMAL-5935431-0001.jpeg',
#  'NORMAL-5940371-0001.jpeg',
#  'NORMAL-5943572-0001.jpeg',
#  'NORMAL-5970247-0001.jpeg',
#  'NORMAL-597494-0001.jpeg',
#  'NORMAL-6002769-0001.jpeg',
#  'NORMAL-6015567-0001.jpeg',
#  'NORMAL-6015860-0001.jpeg',
#  'NORMAL-6044102-0001.jpeg',
#  'NORMAL-6044251-0001.jpeg',
#  'NORMAL-6047821-0001.jpeg',
#  'NORMAL-6054279-0001.jpeg',
#  'NORMAL-6062926-0001.jpeg',
#  'NORMAL-6062926-0002.jpeg',
#  'NORMAL-6073662-0001.jpeg',
#  'NORMAL-6073662-0002.jpeg',
#  'NORMAL-6081265-0001.jpeg',
#  'NORMAL-6084744-0001.jpeg',
#  'NORMAL-6090737-0001.jpeg',
#  'NORMAL-6090737-0002.jpeg',
#  'NORMAL-6095394-0001.jpeg',
#  'NORMAL-6112892-0001.jpeg',
#  'NORMAL-6112892-0002.jpeg',
#  'NORMAL-6116579-0001.jpeg',
#  'NORMAL-6123465-0001.jpeg',
#  'NORMAL-6126748-0001.jpeg',
#  'NORMAL-6137902-0001.jpeg',
#  'NORMAL-6143989-0001.jpeg',
#  'NORMAL-6153007-0001.jpeg',
#  'NORMAL-6156730-0001.jpeg',
#  'NORMAL-618803-0001.jpeg',
#  'NORMAL-6193719-0001.jpeg',
#  'NORMAL-6194746-0001.jpeg',
#  'NORMAL-6205754-0001.jpeg',
#  'NORMAL-6214135-0001.jpeg',
#  'NORMAL-6217600-0001.jpeg',
#  'NORMAL-6219029-0001.jpeg',
#  'NORMAL-6226952-0001.jpeg',
#  'NORMAL-6227100-0001.jpeg',
#  'NORMAL-6237780-0001.jpeg',
#  'NORMAL-6237780-0002.jpeg',
#  'NORMAL-6248376-0001.jpeg',
#  'NORMAL-6251505-0001.jpeg',
#  'NORMAL-6271808-0001.jpeg',
#  'NORMAL-6299880-0001.jpeg',
#  'NORMAL-6309200-0001.jpeg',
#  'NORMAL-6315622-0001.jpeg',
#  'NORMAL-6315622-0002.jpeg',
#  'NORMAL-6319993-0001.jpeg',
#  'NORMAL-6328273-0001.jpeg',
#  'NORMAL-6336339-0001.jpeg',
#  'NORMAL-6346076-0001.jpeg',
#  'NORMAL-6351934-0001.jpeg',
#  'NORMAL-6351934-0002.jpeg',
#  'NORMAL-6357850-0001.jpeg',
#  'NORMAL-6367802-0001.jpeg',
#  'NORMAL-6369415-0001.jpeg',
#  'NORMAL-6369415-0002.jpeg',
#  'NORMAL-6396089-0001.jpeg',
#  'NORMAL-6417148-0001.jpeg',
#  'NORMAL-6430619-0001.jpeg',
#  'NORMAL-6432470-0001.jpeg',
#  'NORMAL-6433176-0001.jpeg',
#  'NORMAL-6433176-0002.jpeg',
#  'NORMAL-6440809-0001.jpeg',
#  'NORMAL-6459868-0001.jpeg',
#  'NORMAL-6462536-0001.jpeg',
#  'NORMAL-6466991-0001.jpeg',
#  'NORMAL-6474092-0001.jpeg',
#  'NORMAL-6474092-0002.jpeg',
#  'NORMAL-6474092-0003.jpeg',
#  'NORMAL-6474092-0004.jpeg',
#  'NORMAL-6478227-0001.jpeg',
#  'NORMAL-6495836-0001.jpeg',
#  'NORMAL-6505040-0001.jpeg',
#  'NORMAL-6505040-0002.jpeg',
#  'NORMAL-6511522-0001.jpeg',
#  'NORMAL-6524946-0001.jpeg',
#  'NORMAL-652570-0001.jpeg',
#  'NORMAL-6533909-0001.jpeg',
#  'NORMAL-6534324-0001.jpeg',
#  'NORMAL-6575898-0001.jpeg',
#  'NORMAL-6593605-0001.jpeg',
#  'NORMAL-6593605-0002.jpeg',
#  'NORMAL-6593605-0003.jpeg',
#  'NORMAL-6619597-0001.jpeg',
#  'NORMAL-6642991-0001.jpeg',
#  'NORMAL-6644501-0001.jpeg',
#  'NORMAL-6644752-0001.jpeg',
#  'NORMAL-6644752-0002.jpeg',
#  'NORMAL-6648483-0001.jpeg',
#  'NORMAL-6661503-0001.jpeg',
#  'NORMAL-6671728-0001.jpeg',
#  'NORMAL-66795-0001.jpeg',
#  'NORMAL-6688691-0001.jpeg',
#  'NORMAL-6702380-0001.jpeg',
#  'NORMAL-6710847-0001.jpeg',
#  'NORMAL-6710847-0002.jpeg',
#  'NORMAL-6712268-0001.jpeg',
#  'NORMAL-6722546-0001.jpeg',
#  'NORMAL-6727820-0001.jpeg',
#  'NORMAL-6731317-0001.jpeg',
#  'NORMAL-673276-0001.jpeg',
#  'NORMAL-678492-0001.jpeg',
#  'NORMAL-678492-0002.jpeg',
#  'NORMAL-6802620-0001.jpeg',
#  'NORMAL-6806808-0001.jpeg',
#  'NORMAL-6830488-0001.jpeg',
#  'NORMAL-6836464-0001.jpeg',
#  'NORMAL-6847348-0001.jpeg',
#  'NORMAL-6847348-0002.jpeg',
#  'NORMAL-6873457-0001.jpeg',
#  'NORMAL-6881695-0001.jpeg',
#  'NORMAL-6882169-0001.jpeg',
#  'NORMAL-6891737-0001.jpeg',
#  'NORMAL-6891737-0002.jpeg',
#  'NORMAL-6891737-0003.jpeg',
#  'NORMAL-6892511-0001.jpeg',
#  'NORMAL-6893621-0001.jpeg',
#  'NORMAL-6897353-0001.jpeg',
#  'NORMAL-6901859-0001.jpeg',
#  'NORMAL-6901859-0002.jpeg',
#  'NORMAL-6901859-0003.jpeg',
#  'NORMAL-6901859-0004.jpeg',
#  'NORMAL-6915237-0001.jpeg',
#  'NORMAL-6931624-0001.jpeg',
#  'NORMAL-6943766-0001.jpeg',
#  'NORMAL-6943766-0002.jpeg',
#  'NORMAL-6943766-0003.jpeg',
#  'NORMAL-6943766-0004.jpeg',
#  'NORMAL-695402-0001.jpeg',
#  'NORMAL-695402-0002.jpeg',
#  'NORMAL-695402-0003.jpeg',
#  'NORMAL-6954688-0001.jpeg',
#  'NORMAL-6954688-0002.jpeg',
#  'NORMAL-6960239-0001.jpeg',
#  'NORMAL-6960239-0002.jpeg',
#  'NORMAL-6960867-0001.jpeg',
#  'NORMAL-6964800-0001.jpeg',
#  'NORMAL-6971619-0001.jpeg',
#  'NORMAL-6972088-0001.jpeg',
#  'NORMAL-6972373-0001.jpeg',
#  'NORMAL-6973172-0001.jpeg',
#  'NORMAL-6973172-0002.jpeg',
#  'NORMAL-6974833-0001.jpeg',
#  'NORMAL-6977054-0001.jpeg',
#  'NORMAL-6978858-0001.jpeg',
#  'NORMAL-6984314-0001.jpeg',
#  'NORMAL-7001302-0001.jpeg',
#  'NORMAL-701579-0001.jpeg',
#  'NORMAL-701579-0002.jpeg',
#  'NORMAL-7019096-0001.jpeg',
#  'NORMAL-7019096-0002.jpeg',
#  'NORMAL-7019096-0003.jpeg',
#  'NORMAL-7033377-0001.jpeg',
#  'NORMAL-7033377-0002.jpeg',
#  'NORMAL-7033377-0003.jpeg',
#  'NORMAL-703667-0001.jpeg',
#  'NORMAL-7049415-0001.jpeg',
#  'NORMAL-7049415-0002.jpeg',
#  'NORMAL-7049415-0003.jpeg',
#  'NORMAL-705219-0001.jpeg',
#  'NORMAL-705219-0002.jpeg',
#  'NORMAL-7054672-0001.jpeg',
#  'NORMAL-705474-0001.jpeg',
#  'NORMAL-705474-0002.jpeg',
#  'NORMAL-7055226-0001.jpeg',
#  'NORMAL-7061098-0001.jpeg',
#  'NORMAL-7061169-0001.jpeg',
#  'NORMAL-7075596-0001.jpeg',
#  'NORMAL-7090700-0001.jpeg',
#  'NORMAL-7091193-0001.jpeg',
#  'NORMAL-7103127-0001.jpeg',
#  'NORMAL-7103127-0002.jpeg',
#  'NORMAL-7103127-0003.jpeg',
#  'NORMAL-7105903-0001.jpeg',
#  'NORMAL-7105903-0002.jpeg',
#  'NORMAL-712032-0001.jpeg',
#  'NORMAL-7123604-0001.jpeg',
#  'NORMAL-7133593-0001.jpeg',
#  'NORMAL-7133593-0002.jpeg',
#  'NORMAL-7138775-0001.jpeg',
#  'NORMAL-7140141-0001.jpeg',
#  'NORMAL-7140141-0002.jpeg',
#  'NORMAL-7140141-0003.jpeg',
#  'NORMAL-7140141-0004.jpeg',
#  'NORMAL-7146748-0001.jpeg',
#  'NORMAL-71482-0001.jpeg',
#  'NORMAL-715046-0001.jpeg',
#  'NORMAL-7155475-0001.jpeg',
#  'NORMAL-7155475-0002.jpeg',
#  'NORMAL-7157255-0001.jpeg',
#  'NORMAL-717388-0001.jpeg',
#  'NORMAL-7181365-0001.jpeg',
#  'NORMAL-7200590-0001.jpeg',
#  'NORMAL-7212555-0001.jpeg',
#  'NORMAL-7218663-0001.jpeg',
#  'NORMAL-7223437-0001.jpeg',
#  'NORMAL-7223437-0002.jpeg',
#  'NORMAL-7228934-0001.jpeg',
#  'NORMAL-7230473-0001.jpeg',
#  'NORMAL-7230473-0002.jpeg',
#  'NORMAL-7233925-0001.jpeg',
#  'NORMAL-7233940-0001.jpeg',
#  'NORMAL-7233940-0002.jpeg',
#  'NORMAL-7236520-0001.jpeg',
#  'NORMAL-7252162-0001.jpeg',
#  'NORMAL-7252162-0002.jpeg',
#  'NORMAL-7252162-0003.jpeg',
#  'NORMAL-7252162-0004.jpeg',
#  'NORMAL-7274084-0001.jpeg',
#  'NORMAL-7274749-0001.jpeg',
#  'NORMAL-7279550-0001.jpeg',
#  'NORMAL-7288289-0001.jpeg',
#  'NORMAL-7298141-0001.jpeg',
#  'NORMAL-7298141-0002.jpeg',
#  'NORMAL-7298793-0001.jpeg',
#  'NORMAL-7301799-0001.jpeg',
#  'NORMAL-7301799-0002.jpeg',
#  'NORMAL-7323530-0001.jpeg',
#  'NORMAL-7323530-0002.jpeg',
#  'NORMAL-7323530-0003.jpeg',
#  'NORMAL-7323530-0004.jpeg',
#  'NORMAL-7327513-0001.jpeg',
#  'NORMAL-7327513-0002.jpeg',
#  'NORMAL-7330624-0001.jpeg',
#  'NORMAL-7333515-0001.jpeg',
#  'NORMAL-7333515-0002.jpeg',
#  'NORMAL-7335645-0001.jpeg',
#  'NORMAL-7368970-0001.jpeg',
#  'NORMAL-7373728-0001.jpeg',
#  'NORMAL-7389271-0001.jpeg',
#  'NORMAL-7397628-0001.jpeg',
#  'NORMAL-7397628-0002.jpeg',
#  'NORMAL-7411302-0001.jpeg',
#  'NORMAL-7419206-0001.jpeg',
#  'NORMAL-7434576-0001.jpeg',
#  'NORMAL-7434654-0001.jpeg',
#  'NORMAL-7436212-0001.jpeg',
#  'NORMAL-7436212-0002.jpeg',
#  'NORMAL-7436212-0003.jpeg',
#  'NORMAL-7444876-0001.jpeg',
#  'NORMAL-7448311-0001.jpeg',
#  'NORMAL-7451061-0001.jpeg',
#  'NORMAL-7461661-0001.jpeg',
#  'NORMAL-7461661-0002.jpeg',
#  'NORMAL-7463705-0001.jpeg',
#  'NORMAL-7469068-0001.jpeg',
#  'NORMAL-74708-0001.jpeg',
#  'NORMAL-7478601-0001.jpeg',
#  'NORMAL-7478601-0002.jpeg',
#  'NORMAL-7483422-0001.jpeg',
#  'NORMAL-7495263-0001.jpeg',
#  'NORMAL-7507366-0001.jpeg',
#  'NORMAL-7534217-0001.jpeg',
#  'NORMAL-7542794-0001.jpeg',
#  'NORMAL-7570480-0001.jpeg',
#  'NORMAL-7575347-0001.jpeg',
#  'NORMAL-7575893-0001.jpeg',
#  'NORMAL-7575893-0002.jpeg',
#  'NORMAL-7605239-0001.jpeg',
#  'NORMAL-7605819-0001.jpeg',
#  'NORMAL-7635797-0001.jpeg',
#  'NORMAL-7635797-0002.jpeg',
#  'NORMAL-7649100-0001.jpeg',
#  'NORMAL-7659145-0001.jpeg',
#  'NORMAL-7662888-0001.jpeg',
#  ...]

# %%
##defining path for train normal data path
train_pneumonia_dir = data_path+'/train/'+class_name[1]

# %%
files_list_pneumonia_train = get_list_of_files(data_path+'/train/'+class_name[1])

# %%
files_list_pneumonia_train
#  'BACTERIA-4531690-0007.jpeg',
#  'BACTERIA-4531690-0008.jpeg',
#  'BACTERIA-4565185-0001.jpeg',
#  'BACTERIA-4577721-0001.jpeg',
#  'BACTERIA-4590061-0001.jpeg',
#  ...]

# %%
test_normal_dir = data_path+'/test/'+class_name[0]
test_pneumonia_dir = data_path+'/test/'+class_name[1]

# %%
files_list_normal_test = get_list_of_files(test_normal_dir)

# %%
files_list_pneumonia_test = get_list_of_files(test_pneumonia_dir)

# %%
print("Number of train samples in Normal category {}".format(len(files_list_normal_train)))
print("Number of train samples in Pneumonia category {}".format(len(files_list_pneumonia_train)))
print("Number of test samples in Normal category {}".format(len(files_list_normal_test)))
print("Number of test samples in Pneumonia category {}".format(len(files_list_pneumonia_test)))
# Out:
# Number of train samples in Normal category 1349
# Number of train samples in Pneumonia category 3883
# Number of test samples in Normal category 234
# Number of test samples in Pneumonia category 390

# %%
rand_img_no = np.random.randint(0,len(files_list_normal_train))

# %%
img = data_path + '/train/NORMAL/'+ files_list_normal_train[rand_img_no]
print(plt.imread(img).shape)
img = mpimg.imread(img)
imgplot = plt.imshow(img)
plt.show()
# Out:
# (1604, 1836)

# %%
img = data_path + '/train/PNEUMONIA/'+ files_list_pneumonia_train[64]
print(plt.imread(img).shape)
img = mpimg.imread(img)
imgplot = plt.imshow(img)
plt.show()
# Out:
# (688, 1128)

# %%
img = data_path + '/test/NORMAL/'+ files_list_normal_test[100]
print(plt.imread(img).shape)
img = mpimg.imread(img)
imgplot = plt.imshow(img)
plt.show()
# Out:
# (1352, 1562)

# %%
img = data_path + '/test/PNEUMONIA/'+ files_list_pneumonia_test[2]
print(plt.imread(img).shape)
img = mpimg.imread(img)
imgplot = plt.imshow(img)
plt.show()
# Out:
# (752, 1032)

# %% [markdown]
# ## Transforming the Images

# %% [markdown]
# **Data Transformation Overview**
#
# We need to perform transformation on both train and test images. For Training data, we need to perform data augmentation as well. Data Augmentation is done to create synthetic data.
#
# **Transformation Steps**
#
# In Transformation, we are applying the following operations:
#
# - **Resize:**
#   - Resize the input image to the given size.
#
# - **CenterCrop:**
#   - Crops the given image at the center.
#
# - **ColorJitter:**
#   - Randomly change the brightness, contrast, saturation, and hue of an image.
#
# - **RandomHorizontalFlip:**
#   - Horizontally flip the given image randomly with a given probability.
#
# - **RandomRotation:**
#   - Rotate the image by a specified angle.
#
# - **ToTensor:**
#   - Convert numpy.ndarray to tensor.
#
# - **Normalize:**
#   - Normalize a float tensor image with mean and standard deviation.
#
# These transformations help in preparing the data for training machine learning models by ensuring consistency and providing augmented data for improved generalization.

# %%
#defining the image transformations to be applied to the images
train_transform = transforms.Compose([
    transforms.Resize(224),
    transforms.CenterCrop(224),
    transforms.ColorJitter(brightness=0.10, contrast=0.1, saturation=0.10, hue=0.1),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                          [0.229, 0.224, 0.225])
])

# %%
#test transformations
test_transform = transforms.Compose([
    transforms.Resize(224),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                          [0.229, 0.224, 0.225])
])

# %% [markdown]
# ## Creating Data Loader

# %% [markdown]
# For our usecase will be using the default data loader for Pytorch.
#
# - We will be creating 2 data loaders one for the training data and other for the test data.
# - batch size is a hyperparameter which we can tweak according to our need and system configuration.
# - We can provide Image shuffling True for training data and False for test data.
# - Pin memory is used to transfer the loaded dataset from CPU to GPU.

# %%
train_data = datasets.ImageFolder(os.path.join(data_path, 'train'), transform= train_transform)

# %%
train_data
# Out:
# Dataset ImageFolder
#     Number of datapoints: 5232
#     Root location: c:\Users\hp\Desktop\deeplearningproject\artifacts\02_25_2024_00_54_27\data_ingestion\chest_xray\train
#     StandardTransform
# Transform: Compose(
#                Resize(size=224, interpolation=bilinear, max_size=None, antialias=None)
#                CenterCrop(size=(224, 224))
#                ColorJitter(brightness=[0.9, 1.1], contrast=[0.9, 1.1], saturation=[0.9, 1.1], hue=[-0.1, 0.1])
#                RandomHorizontalFlip(p=0.5)
#                RandomRotation(degrees=[-10.0, 10.0], interpolation=nearest, expand=False, fill=0)
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )

# %%
test_data = datasets.ImageFolder(os.path.join(data_path, 'test'), transform= test_transform)

# %%
test_data
# Out:
# Dataset ImageFolder
#     Number of datapoints: 624
#     Root location: c:\Users\hp\Desktop\deeplearningproject\artifacts\02_25_2024_00_54_27\data_ingestion\chest_xray\test
#     StandardTransform
# Transform: Compose(
#                Resize(size=224, interpolation=bilinear, max_size=None, antialias=None)
#                CenterCrop(size=(224, 224))
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )

# %%
train_loader = DataLoader(train_data,
                          batch_size= 2, shuffle= True, pin_memory= True)

# %%
test_loader = DataLoader(test_data,
                         batch_size= 2, shuffle= False, pin_memory= True)

# %%
class_names = train_data.classes
print(class_names)
print(f'Number of train images: {len(train_data)}')
print(f'Number of test images: {len(test_data)}')
# Out:
# ['NORMAL', 'PNEUMONIA']
# Number of train images: 5232
# Number of test images: 624

# %% [markdown]
# ## Creating the model Architecture

# %% [markdown]
# - First Layer is the input layer consisting of 3 input channels and output channels with kernel_size of 3X3, padding=0 and bias=True. The activation function we are using is ReLU and performing batch normalization.
# - Then we are performing max pooling to extract the important features out of the image.
# - Similarly we are passing our model through 9 convolutional layers.
# - Finally we are passing out passing our model through a output layer in which we are getting binary classification.

# %% [markdown]
# **Think of a Convolutional Block as a Detective:**
#
# *Investigation (Convolution):*
#
# - Imagine a detective looking at a crime scene (input image).
#
# - The detective is trying to find important clues (features) to solve the case.
# - Each convolutional layer is like the detective examining a specific part of the crime scene.
#
# *Checking for Clues (ReLU Activation):*
#
# - After looking at a part of the crime scene, the detective decides whether the clues found are important or not.
# -ReLU activation is like the detective saying, "If a clue is useful, keep it; otherwise, ignore it."
#
# *Organizing Clues (Batch Normalization):*
#
# - The detective wants to keep things organized and consistent.
# - Batch normalization is like the detective putting all the important clues in a neat and organized manner.
#
# *Getting a Bigger Picture (MaxPooling):*
#
# - Now, the detective wants to get a bigger picture of the crime scene.
# - MaxPooling is like the detective stepping back and summarizing what was found in a specific area.
#
# **Why MaxPooling After Every Convolution?**
#
# **Seeing Different Perspectives:**
#
# - Each convolutional layer looks at the crime scene from a different angle (captures different features).
# MaxPooling helps the detective see a broader view after each close examination.
# Making Information Manageable:
#
# - Imagine if the detective took pictures of every small detail; it would be overwhelming.
# MaxPooling helps reduce the information to the most important aspects, making the investigation more manageable.
# Improving Detective Skills:
#
# - By going through this process multiple times, the detective becomes more skilled at recognizing important clues and solving the case.

# %%
class Net(nn.Module):
    def __init__(self):
        """
        Creating custom CNN architecture for Image classification
        """
        super(Net, self).__init__()
        # Input Block
        self.convolution_block1 = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=8, kernel_size=(3, 3),
                      padding=0, bias=True),
            nn.ReLU(),
            nn.BatchNorm2d(8)
        )
        self.pooling11 = nn.MaxPool2d(2, 2)
        # CONVOLUTION BLOCK 1
        self.convolution_block2 = nn.Sequential(
            nn.Conv2d(in_channels=8, out_channels=20, kernel_size=(3, 3),
                      padding=0, bias=True),
            nn.ReLU(),
            nn.BatchNorm2d(20)
        )
        self.pooling22 = nn.MaxPool2d(2, 2)
        self.convolution_block3 = nn.Sequential(
            nn.Conv2d(in_channels=20, out_channels=10, kernel_size=(1, 1), padding=0, bias=True),
            nn.ReLU(),
            nn.BatchNorm2d(10),
        )
        self.pooling33 = nn.MaxPool2d(2, 2)
        # CONVOLUTION BLOCK 2
        self.convolution_block4 = nn.Sequential(
            nn.Conv2d(in_channels=10, out_channels=20, kernel_size=(3, 3), padding=0, bias=True),
            nn.ReLU(),
            nn.BatchNorm2d(20)
        )
        self.convolution_block5 = nn.Sequential(
            nn.Conv2d(in_channels=20, out_channels=32, kernel_size=(1, 1), padding=0, bias=True),
            nn.ReLU(),
            nn.BatchNorm2d(32),
        )
#         self.convblock6 = nn.Sequential(
#             nn.Conv2d(in_channels=32, out_channels=10, kernel_size=(1, 1), padding='same', bias=True),
#             nn.ReLU(),
#             nn.BatchNorm2d(10),
#         )
        self.convolution_block6 = nn.Sequential(
            nn.Conv2d(in_channels=32, out_channels=10, kernel_size=(3, 3), padding=0, bias=True),
            nn.ReLU(),
            nn.BatchNorm2d(10)
        )
#         self.convblock8 = nn.Sequential(
#             nn.Conv2d(in_channels=10, out_channels=32, kernel_size=(1, 1), padding='same', bias=True),
#             nn.ReLU(),
#             nn.BatchNorm2d(32)
#         )
        self.convolution_block7 = nn.Sequential(
            nn.Conv2d(in_channels=10, out_channels=10, kernel_size=(1, 1), padding=0, bias=True),
            nn.ReLU(),
            nn.BatchNorm2d(10)
        )
        self.convolution_block8 = nn.Sequential(
            nn.Conv2d(in_channels=10, out_channels=14, kernel_size=(3, 3), padding=0, bias=True),
            nn.ReLU(),
            nn.BatchNorm2d(14)
        )
        self.convolution_block9 = nn.Sequential(
            nn.Conv2d(in_channels=14, out_channels=16, kernel_size=(3, 3), padding=0, bias=True),
            nn.ReLU(),
            nn.BatchNorm2d(16)
        )
        # OUTPUT BLOCK
        self.gap = nn.Sequential(
            nn.AvgPool2d(kernel_size=4)
        )
        self.convolution_block_out = nn.Sequential(
              nn.Conv2d(in_channels=16, out_channels=2, kernel_size=(4, 4), padding=0, bias=True),
        )
    def forward(self, x):
        x = self.convolution_block1(x)
        x = self.pooling11(x)
        x = self.convolution_block2(x)
        x = self.pooling22(x)
        x = self.convolution_block3(x)
        x = self.pooling33(x)
        x = self.convolution_block4(x)
        x = self.convolution_block5(x)
#         x = self.convblock6(x)
        x = self.convolution_block6(x)
#         x = self.convblock8(x)
        x = self.convolution_block7(x)
        x = self.convolution_block8(x)
        x = self.convolution_block9(x)
        x = self.gap(x)
        x = self.convolution_block_out(x)
        x = x.view(-1, 2)
        return F.log_softmax(x, dim=-1)

# %%
# To check weather cuda is available in the system or not 
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
print("Available processor {}".format(device))
model = Net().to(device)
# To check the model summary
summary(model, input_size=(3, 224, 224))
# Out:
# Available processor cpu
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 8, 222, 222]             224
#               ReLU-2          [-1, 8, 222, 222]               0
#        BatchNorm2d-3          [-1, 8, 222, 222]              16
#          MaxPool2d-4          [-1, 8, 111, 111]               0
#             Conv2d-5         [-1, 20, 109, 109]           1,460
#               ReLU-6         [-1, 20, 109, 109]               0
#        BatchNorm2d-7         [-1, 20, 109, 109]              40
#          MaxPool2d-8           [-1, 20, 54, 54]               0
#             Conv2d-9           [-1, 10, 54, 54]             210
#              ReLU-10           [-1, 10, 54, 54]               0
#       BatchNorm2d-11           [-1, 10, 54, 54]              20
#         MaxPool2d-12           [-1, 10, 27, 27]               0
#            Conv2d-13           [-1, 20, 25, 25]           1,820
#              ReLU-14           [-1, 20, 25, 25]               0
#       BatchNorm2d-15           [-1, 20, 25, 25]              40
#            Conv2d-16           [-1, 32, 25, 25]             672
#              ReLU-17           [-1, 32, 25, 25]               0
#       BatchNorm2d-18           [-1, 32, 25, 25]              64
#            Conv2d-19           [-1, 10, 23, 23]           2,890
#              ReLU-20           [-1, 10, 23, 23]               0
#       BatchNorm2d-21           [-1, 10, 23, 23]              20
#            Conv2d-22           [-1, 10, 23, 23]             110
#              ReLU-23           [-1, 10, 23, 23]               0
#       BatchNorm2d-24           [-1, 10, 23, 23]              20
#            Conv2d-25           [-1, 14, 21, 21]           1,274
#              ReLU-26           [-1, 14, 21, 21]               0
#       BatchNorm2d-27           [-1, 14, 21, 21]              28
#            Conv2d-28           [-1, 16, 19, 19]           2,032
#              ReLU-29           [-1, 16, 19, 19]               0
#       BatchNorm2d-30           [-1, 16, 19, 19]              32
#         AvgPool2d-31             [-1, 16, 4, 4]               0
#            Conv2d-32              [-1, 2, 1, 1]             514
# ================================================================
# Total params: 11,486
# Trainable params: 11,486
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 17.64
# Params size (MB): 0.04
# Estimated Total Size (MB): 18.26
# ----------------------------------------------------------------

# %%
train_losses = []
test_losses = []
train_acc = []
test_acc = []

# %%
def train(model, device, train_loader, optimizer, epoch):
    """
    Description: To train the model 
    
    input: model,device,train_loader,optimizer,epoch 
    
    output: loss, batch id and accuracy
    """
    model.train()
    pbar = tqdm(train_loader)
    correct = 0
    processed = 0
    for batch_idx, (data, target) in enumerate(pbar):
        # get data
        data, target = data.to(device), target.to(device)
        # Initialization of gradient
        optimizer.zero_grad()
        # In PyTorch, gradient is accumulated over backprop and even though thats used in RNN generally not used in CNN
        # or specific requirements
        ## prediction on data
        y_pred = model(data)
        # Calculating loss given the prediction
        loss = F.nll_loss(y_pred, target)
        train_losses.append(loss)
        # Backprop
        loss.backward()
        optimizer.step()
        # get the index of the log-probability corresponding to the max value
        pred = y_pred.argmax(dim=1, keepdim=True)
        correct += pred.eq(target.view_as(pred)).sum().item()
        processed += len(data)
        pbar.set_description(desc= f'Loss={loss.item()} Batch_id={batch_idx} Accuracy={100*correct/processed:0.2f}')
        train_acc.append(100*correct/processed)

# %%
def test(model, device, test_loader):
    """
    Description: To test the model
    
    input: model, device, test_loader
    
    output: average loss and accuracy
    
    """
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item()
            pred = output.argmax(dim=1, keepdim=True)
            correct += pred.eq(target.view_as(pred)).sum().item()
    test_loss /= len(test_loader.dataset)
    test_losses.append(test_loss)
    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.2f}%)\n'.format(
            test_loss, correct, len(test_loader.dataset),
            100. * correct / len(test_loader.dataset)))
    test_acc.append(100. * correct / len(test_loader.dataset))

# %%
# Defining the params for training 
model =  Net().to(device)
optimizer = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.8)
scheduler = StepLR(optimizer, step_size=6, gamma=0.5)
EPOCHS = 1

# %%
#Training the model
for epoch in range(EPOCHS):
    print("EPOCH:", epoch)
    train(model, device, train_loader, optimizer, epoch)
    scheduler.step()
    print('current Learning Rate: ', optimizer.state_dict()["param_groups"][0]["lr"])
    test(model, device, test_loader)
# Out:
# EPOCH: 0
# Loss=0.040712811052799225 Batch_id=2615 Accuracy=90.67: 100%|██████████| 2616/2616 [03:57<00:00, 11.00it/s]
# current Learning Rate:  0.01
#
# Test set: Average loss: 0.5240, Accuracy: 508/624 (81.41%)

# %%
train_losses1 = [float(i.cpu().detach().numpy()) for i in train_losses]
train_acc1 = [i for i in train_acc]
test_losses1 = [i for i in test_losses]
test_acc1 = [i for i in test_acc]
fig, axs = plt.subplots(2,2,figsize=(16,10))
axs[0, 0].plot(train_losses1)
axs[0, 0].set_title("Training Loss")

axs[1, 0].plot(train_acc1)
axs[1, 0].set_title("Training Accuracy")

axs[0, 1].barplot(test_losses1)
axs[0, 1].set_title("Test Loss")

axs[1, 1].plot(test_acc1)
axs[1, 1].set_title("Test Accuracy")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 train_losses1 = [float(i.cpu().detach().numpy()) for i in train_losses]
#       2 train_acc1 = [i for i in train_acc]
#       3 test_losses1 = [i for i in test_losses]
#
# NameError: name 'train_losses' is not defined

# %%
print("Test Losses:", test_losses1)
print("Test Accuracy:", test_acc1)
# Out:
# Test Losses: [0.5239745680162462]
# Test Accuracy: [81.41025641025641]

# %%
test_losses1
# Out:
# [0.5239745680162462]

# %%
test_losses
# Out:
# [0.5239745680162462]

# %%
test_acc
# Out:
# [81.41025641025641]

# %%
test_acc1
# Out:
# [81.41025641025641]
